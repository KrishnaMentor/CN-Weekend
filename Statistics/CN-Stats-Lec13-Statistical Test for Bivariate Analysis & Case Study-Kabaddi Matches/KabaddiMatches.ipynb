# %%
# Importing all the dependencies requried for the Case Study ...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events_df = pd.read_csv("DS_events.csv", low_memory = False)
events_df.sample(10)
# Out:
#        Column1  clock  defender_id  defenders  defending_all_out_points  \
# 8533        88  34:34          NaN        NaN                       NaN
# 15805       50  18:32       2657.0        NaN                       0.0
# 34428       76  06:18          NaN        NaN                       NaN
# 61702       44  18:07          NaN        NaN                       0.0
# 54719       17  12:34          NaN        NaN                       NaN
# 60239       91  01:35          NaN        NaN                       NaN
# 21942       14  06:28        360.0        NaN                       NaN
# 33878       85  08:08          NaN        NaN                       NaN
# 3519        18  08:13          NaN        NaN                       NaN
# 32981       86  04:00          NaN        NaN                       NaN
#
#        defending_bonus_points  defending_capture_points  defending_points  \
# 8533                      NaN                       NaN               NaN
# 15805                     0.0                       1.0               1.0
# 34428                     NaN                       NaN               0.0
# 61702                     0.0                       0.0               0.0
# 54719                     NaN                       NaN               NaN
# 60239                     NaN                       NaN               NaN
# 21942                     NaN                       NaN               1.0
# 33878                     NaN                       NaN               0.0
# 3519                      NaN                       NaN               0.0
# 32981                     NaN                       NaN               0.0
#
#        defending_team_id  defending_technical_points  ... review.reason.id  \
# 8533                 NaN                         NaN  ...              NaN
# 15805               30.0                         0.0  ...              NaN
# 34428                5.0                         NaN  ...              NaN
# 61702                8.0                         0.0  ...              NaN
# 54719                NaN                         NaN  ...              NaN
# 60239                NaN                         NaN  ...              NaN
# 21942                2.0                         NaN  ...              NaN
# 33878               30.0                         NaN  ...              NaN
# 3519                 1.0                         NaN  ...              NaN
# 32981                4.0                         NaN  ...              NaN
#
#       review.reason.reason_value  review.review_taken  review.team_id  \
# 8533                         NaN                  NaN             NaN
# 15805                        NaN                False             0.0
# 34428                        NaN                  NaN             NaN
# 61702                        NaN                False             0.0
# 54719                        NaN                  NaN             NaN
# 60239                        NaN                  NaN             NaN
# 21942                        NaN                  NaN             NaN
# 33878                        NaN                  NaN             NaN
# 3519                         NaN                  NaN             NaN
# 32981                        NaN                  NaN             NaN
#
#           score  status_id  substituted_by  super_raid  super_tackle  team_id
# 8533        NaN        NaN             NaN         NaN           NaN      7.0
# 15805  [13, 13]        3.0             NaN       False         False      NaN
# 34428  [23, 38]        0.0             NaN         NaN           NaN      NaN
# 61702  [28, 17]        3.0             NaN       False         False      NaN
# 54719       NaN        2.0             NaN         NaN           NaN      0.0
# 60239       NaN        3.0           708.0         NaN           NaN      3.0
# 21942    [4, 4]        NaN             NaN         NaN           NaN      NaN
# 33878  [23, 25]        0.0             NaN         NaN           NaN      NaN
# 3519     [4, 7]        NaN             NaN         NaN           NaN      NaN
# 32981  [21, 23]        0.0             NaN         NaN           NaN      NaN
#
# [10 rows x 41 columns]
